# %%
from bj_monte_carlo import BJAgent_MonteCarlo
from bj_temporal_difference import BJAgent_TemporalDifference
from bj_sarsa import BJAgent_Sarsa
from bj_q_learning import BJAgent_QLearning

# %%
# agent = BJAgent_MonteCarlo()
# agent = BJAgent_TemporalDifference()
# agent = BJAgent_Sarsa()
agent = BJAgent_QLearning()

# %%
agent.reset_learning()

# Others
#history = agent.learn(iterations=2_000, final_epsilon=0.01, validate_each_iteration=50, verbose=True)

# QLearning
history = agent.learn(iterations=2000, final_epsilon=0.05, epsilon_val=0, validate_each_iteration=5, verbose=True)
# Out:
# Episode:          5, epsilon: 0.99403, Win: 2652, Lose: 7348, Win rate: 0.265
# Episode:         10, epsilon: 0.98661, Win: 2631, Lose: 7369, Win rate: 0.263
# Episode:         15, epsilon: 0.97925, Win: 2532, Lose: 7468, Win rate: 0.253
# Episode:         20, epsilon: 0.97194, Win: 2593, Lose: 7407, Win rate: 0.259
# Episode:         25, epsilon: 0.96469, Win: 2959, Lose: 7041, Win rate: 0.296
# Episode:         30, epsilon: 0.95749, Win: 3054, Lose: 6946, Win rate: 0.305
# Episode:         35, epsilon: 0.95035, Win: 3013, Lose: 6987, Win rate: 0.301
# Episode:         40, epsilon: 0.94326, Win: 2986, Lose: 7014, Win rate: 0.299
# Episode:         45, epsilon: 0.93622, Win: 3092, Lose: 6908, Win rate: 0.309
# Episode:         50, epsilon: 0.92923, Win: 3160, Lose: 6840, Win rate: 0.316
# Episode:         55, epsilon: 0.92230, Win: 3005, Lose: 6995, Win rate: 0.300
# Episode:         60, epsilon: 0.91542, Win: 3231, Lose: 6769, Win rate: 0.323
# ...

# %%
agent.plot_history()

# %%
agent.close()
